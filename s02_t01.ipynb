# %% [markdown]
# # Sprint 2 - IT Academy

# %% [markdown]
# ## - [x] _Ejercicio 1_
# ## - [x] _Ejercicio 2_
# _Calculos Sencillos_

# %%
#Crear variables:
a = 153
b = 10

#Operaciones matematicas simples
results = a/b

#casting
print("This is a test "+str(results))
# Out:
# This is a test 15.3

# %%
#Tecnicas con Strings y Booleans

if b > a:
  print("b es mayor que a")
else:
  print("b es mayor que a")
# Out:
# b es mayor que a

# %%
sprint = [1,2,3,4,5]
print(sprint[-1])
# Out:
# 5

# %%
stage = 2
sprints = 18
if stage < sprints:
    print("Aun falta para el curso")
# Out:
# Aun falta para el curso

# %% [markdown]
# ## - [  ] _Ejercicio 3_

# %% [markdown]
# **Primeros ejercicios del itinerario de Data Science**
# ![python-que-es.jpg](attachment:python-que-es.jpg)
# ---
# ~~code is fun~~

# %% [markdown]
# * **Primero se instalo:**
#     * Anaconda +
#     * Python +
#     * Jupyter notebook
#
# * **Segundo:**
#     * Se hacen calculos basicos
#
# * **Tercero:**
#     * Se crean listas, titulos
#     * Se cambian estilos
#     * Se añaden imagenes

# %%
import nbconvert

# %% [markdown]
# ## Nivel 2
# ### Exportar a html y pdf

# %%
# !jupyter nbconvert  s02_t01.ipynb --to html
# Out:
# [NbConvertApp] Converting notebook s02_t01.ipynb to html
# [NbConvertApp] Writing 576815 bytes to s02_t01.html

# %%
# !jupyter nbconvert  s02_t01.ipynb --to pdf
# Out:
# [NbConvertApp] Converting notebook s02_t01.ipynb to pdf
# [NbConvertApp] Writing 37062 bytes to s02_t01.pdf

# %% [markdown]
# ## Nivel 3
# ### Instalar extensiones

# %% [markdown]
# El procedimiento para instalar la extension nbextensions se realizo primero como
# * conda install upyter_contrib_nbextensions
# Despues ha sido importado en el notebook:

# %%
import jupyter_contrib_nbextensions
